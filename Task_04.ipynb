# %% [markdown]
# # Sani Talukder
# #Reg. no: 2017331023

# %% [markdown]
# **Frequency Modulation**

# %%
import numpy as np
import matplotlib.pyplot as plt

modulator_frequency = 2.0
carrier_frequency = 30.0
modulation_index = 1.0

time = np.arange(20000.0) / 20000.0
modulator = np.sin(2.0 * np.pi * modulator_frequency * time) * modulation_index
carrier = np.sin(2.0 * np.pi * carrier_frequency * time)
product = np.zeros_like(modulator)

for i, t in enumerate(time):
    product[i] = np.sin(2. * np.pi * (carrier_frequency * t + modulator[i]))

plt.subplot(3, 1, 1)
plt.title('Frequency Modulation')
plt.plot(modulator)
plt.ylabel('Amplitude')
plt.xlabel('Modulator signal')
# Out:
# Text(0.5, 0, 'Modulator signal')

# %%
plt.subplot(3, 1, 2)
plt.plot(carrier)
plt.ylabel('Amplitude')
plt.xlabel('Carrier signal')
# Out:
# Text(0.5, 0, 'Carrier signal')

# %%
plt.subplot(3, 1, 3)
plt.plot(product)
plt.ylabel('Amplitude')
plt.xlabel('Output signal')
plt.show()

# %% [markdown]
# **Amplitude Modulation**

# %%
import numpy as np
import matplotlib.pyplot as plt

#Carrier wave c(t)=A_c*cos(2*pi*f_c*t)
#Modulating wave m(t)=A_m*cos(2*pi*f_m*t)
#Modulated wave s(t)=A_c[1+mu*cos(2*pi*f_m*t)]cos(2*pi*f_c*t)

A_c = 100
f_c = 120
A_m = 100
f_m = 200
modulation_index = 2

t = np.linspace(0, 1, 1000)

carrier = A_c*np.cos(2*np.pi*f_c*t)
modulator = A_m*np.cos(2*np.pi*f_m*t)
product = A_c*(1+modulation_index*np.cos(2*np.pi*f_m*t))*np.cos(2*np.pi*f_c*t)

plt.subplot(3,1,1)
plt.title('Amplitude Modulation')
plt.plot(modulator,'g')
plt.ylabel('Amplitude')
plt.xlabel('Message signal')

plt.subplot(3,1,2)
plt.plot(carrier, 'r')
plt.ylabel('Amplitude')
plt.xlabel('Carrier signal')

plt.subplot(3,1,3)
plt.plot(product, color="purple")
plt.ylabel('Amplitude')
plt.xlabel('AM signal')

plt.subplots_adjust(hspace=1)
plt.rc('font', size=15)
fig = plt.gcf()
fig.set_size_inches(16, 9)

fig.savefig('Amplitude Modulation.png', dpi=100)

# %% [markdown]
# **Phase modulation**

# %%
ac=3; 
fc=2; 
t=np.arange(0, 3.0, 0.0001)
phase = 0
c=ac*np.sin(2*np.pi*fc*t + phase); 


plt.figure(figsize=(10, 5))
plt.plot(t, c)
plt.show()

# %%
k = 1.0
fm=3
am = 2
m=am*np.sin(2 * np.pi*fm*t)

plt.figure(figsize=(10, 5))
plt.plot(t, m)
plt.show()

# %%
y=Ac*np.sin((2*np.pi*fc*t) + (k * m + phase))
  
plt.figure(figsize=(10, 5))
plt.plot(t, y)
plt.show()
